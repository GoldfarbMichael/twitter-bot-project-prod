# %% [markdown]
# # Imports #

# %%
import os
import pandas as pd
from tqdm import tqdm
from collections import Counter

# %% [markdown]
# # Get unique ID's #

# %%
input_dir = "../data/twitter_proc/files"
user_counter = Counter()

for file_name in tqdm(os.listdir(input_dir), desc="Scanning files for user IDs"):
    if file_name.endswith(".csv"):
        file_path = os.path.join(input_dir, file_name)
        try:
            df = pd.read_csv(file_path, usecols=["userid"])
            user_counter.update(df["userid"].dropna())
        except Exception as e:
            print(f"Skipping {file_name}: {e}")
            continue

# Convert counter to DataFrame
df_unique = pd.DataFrame(list(user_counter.items()), columns=["userid", "count"])

print("Number of unique users:", df_unique.shape[0])
print(df_unique.head())
# Out:
# Scanning files for user IDs: 100%|██████████| 290/290 [02:29<00:00,  1.93it/s]
# Number of unique users: 2389688
#                 userid  count
# 0            173212647     54
# 1            335041409     27
# 2  1512400441103032323   1410
# 3  1356632630662430722    261
# 4             20297125     16

# %% [markdown]
# # Delete labeled users #

# %%
# Load the intersection user IDs
intersection_df = pd.read_csv('../data/labeled_intersection.csv', usecols=['userid'])
intersection_userids = set(intersection_df['userid'])

# Filter df_unique to exclude intersecting userids
df_unique_filtered = df_unique[~df_unique['userid'].isin(intersection_userids)].copy()
del df_unique
# Out:
# Filtered unique users saved. Remaining rows: 2285391
#                 userid  count
# 0            173212647     54
# 1            335041409     27
# 2  1512400441103032323   1410
# 3  1356632630662430722    261
# 4             20297125     16

# %% [markdown]
# # totaltweets #

# %%
def scan_and_aggregate(input_dir, target_col, agg_func, userid_col="userid"):
    """
    Scans all CSVs in a directory and aggregates target_col per userid using agg_func.

    Returns:
        pd.DataFrame with columns: [userid, target_col]
    """
    aggregated = {}

    for file_name in tqdm(os.listdir(input_dir), desc=f"Scanning '{target_col}'"):
        if not file_name.endswith(".csv"):
            continue
        file_path = os.path.join(input_dir, file_name)

        try:
            df = pd.read_csv(file_path, usecols=[userid_col, target_col])
            df = df.dropna(subset=[userid_col, target_col])

            # Group by userid and aggregate
            grouped = df.groupby(userid_col)[target_col].agg(agg_func)

            for uid, value in grouped.items():
                if uid not in aggregated:
                    aggregated[uid] = value
                else:
                    aggregated[uid] = agg_func([aggregated[uid], value])

        except Exception as e:
            print(f"⚠️ Skipping {file_name}: {e}")
            continue

    return pd.DataFrame(list(aggregated.items()), columns=[userid_col, target_col])


df_totaltweets = scan_and_aggregate(input_dir, target_col="totaltweets", agg_func=max)
df_unique_filtered = df_unique_filtered.merge(df_totaltweets, on="userid", how="left")
del df_totaltweets
# Out:
# Scanning 'totaltweets':   0%|          | 0/290 [00:00<?, ?it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':   0%|          | 1/290 [00:00<02:28,  1.94it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':   1%|          | 2/290 [00:00<02:05,  2.30it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':   1%|          | 3/290 [00:01<02:01,  2.36it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':   1%|▏         | 4/290 [00:01<01:53,  2.52it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':   2%|▏         | 5/290 [00:02<01:51,  2.56it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':   2%|▏         | 6/290 [00:02<02:04,  2.28it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':
/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  38%|███▊      | 110/290 [00:46<01:04,  2.78it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# ...
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  87%|████████▋ | 253/290 [02:17<00:10,  3.66it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  88%|████████▊ | 254/290 [02:18<00:10,  3.39it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  88%|████████▊ | 255/290 [02:18<00:11,  2.93it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  88%|████████▊ | 256/290 [02:19<00:11,  2.99it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  89%|████████▊ | 257/290 [02:19<00:11,  2.85it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  89%|████████▉ | 258/290 [02:20<00:17,  1.85it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  89%|████████▉ | 259/290 [02:20<00:14,  2.16it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  90%|████████▉ | 260/290 [02:20<00:12,  2.49it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  90%|█████████ | 261/290 [02:21<00:12,  2.36it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  90%|█████████ | 262/290 [02:21<00:11,  2.44it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  91%|█████████ | 263/290 [02:22<00:10,  2.52it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  91%|█████████ | 264/290 [02:22<00:09,  2.86it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  91%|█████████▏| 265/290 [02:23<00:12,  1.95it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  92%|█████████▏| 266/290 [02:23<00:11,  2.12it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  92%|█████████▏| 267/290 [02:23<00:09,  2.39it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  92%|█████████▏| 268/290 [02:24<00:07,  2.80it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  93%|█████████▎| 269/290 [02:24<00:06,  3.29it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  93%|█████████▎| 270/290 [02:24<00:05,  3.79it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  93%|█████████▎| 271/290 [02:24<00:04,  4.22it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  94%|█████████▍| 273/290 [02:24<00:02,  5.69it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  94%|█████████▍| 274/290 [02:25<00:02,  5.65it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  95%|█████████▍| 275/290 [02:25<00:02,  5.35it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  95%|█████████▌| 276/290 [02:25<00:02,  6.06it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  96%|█████████▌| 277/290 [02:25<00:02,  6.23it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  96%|█████████▌| 279/290 [02:26<00:02,  4.45it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  97%|█████████▋| 280/290 [02:26<00:02,  3.36it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  97%|█████████▋| 281/290 [02:27<00:03,  2.81it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  97%|█████████▋| 282/290 [02:28<00:03,  2.07it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  98%|█████████▊| 283/290 [02:28<00:02,  2.35it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  98%|█████████▊| 284/290 [02:29<00:03,  1.78it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  98%|█████████▊| 285/290 [02:30<00:03,  1.50it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  99%|█████████▊| 286/290 [02:30<00:02,  1.49it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  99%|█████████▉| 287/290 [02:31<00:02,  1.47it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets':  99%|█████████▉| 288/290 [02:32<00:01,  1.30it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets': 100%|█████████▉| 289/290 [02:33<00:00,  1.10it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'totaltweets': 100%|██████████| 290/290 [02:34<00:00,  1.88it/s]

# %%
print("Number of unique users:", df_unique_filtered.shape[0])
print(df_unique_filtered.head())
# Out:
# Number of unique users: 2285391
#                 userid  count  totaltweets
# 0            173212647     54         6808
# 1            335041409     27        79454
# 2  1512400441103032323   1410         2610
# 3  1356632630662430722    261          955
# 4             20297125     16        61432

# %% [markdown]
# # Get following and followers and acctdesc #

# %%
import os
from tqdm import tqdm

def extract_latest_follow_acctdesc_stats(input_dir, known_userids,
                                 userid_col="userid", ts_col="tweetcreatedts",
                                 followers_col="followers", following_col="following", acctdesc_col="acctdesc"):

    latest_info = {}  # userid → (timestamp, followers, following)
    known_userids_set = set(known_userids)

    for file in tqdm(os.listdir(input_dir), desc="Scanning files"):
        if not file.endswith(".csv"):
            continue
        path = os.path.join(input_dir, file)

        try:
            df = pd.read_csv(path, usecols=[userid_col, ts_col, followers_col, following_col, acctdesc_col])
        except Exception as e:
            print(f"⚠️ Skipping {file}: {e}")
            continue

        df = df[df[userid_col].isin(known_userids_set)]
        df = df.dropna(subset=[userid_col, ts_col, followers_col, following_col])

        # Parse timestamps
        df[ts_col] = pd.to_datetime(df[ts_col], errors='coerce')
        df = df.dropna(subset=[ts_col])

        for row in df.itertuples(index=False):
            uid = getattr(row, userid_col)
            ts = getattr(row, ts_col)
            followers = getattr(row, followers_col)
            following = getattr(row, following_col)
            acctdesc = getattr(row, acctdesc_col)

            if uid not in latest_info or ts > latest_info[uid][0]:
                latest_info[uid] = (ts, followers, following, acctdesc)

    # Create a dataframe from the final dict
    df_result = pd.DataFrame([
        (uid, data[1], data[2], data[3]) for uid, data in latest_info.items()
    ], columns=[userid_col, "followers", "following", "acctdesc"])

    return df_result

df_follow_stats = extract_latest_follow_acctdesc_stats(
    input_dir=input_dir,
    known_userids=df_unique_filtered["userid"]
)

# Merge the result into your main dataframe
df_unique_filtered = df_unique_filtered.merge(df_follow_stats, on="userid", how="left")
# Out:
# Scanning files: 100%|██████████| 290/290 [10:42<00:00,  2.22s/it]

# %% [markdown]
# # AVG retweet count #

# %%
df_retweet_sum = scan_and_aggregate(input_dir=input_dir,target_col="retweetcount", agg_func=sum)
df_unique_filtered = df_unique_filtered.merge(df_retweet_sum, on="userid", how="left")
df_unique_filtered["avg_retweetcount"] = (
    df_unique_filtered["retweetcount"] / df_unique_filtered["count"]
)
df_unique_filtered.drop(columns=["retweetcount"], inplace=True)
# Out:
# Scanning 'retweetcount':   0%|          | 0/290 [00:00<?, ?it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   0%|          | 1/290 [00:00<02:03,  2.35it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   1%|          | 2/290 [00:00<01:41,  2.83it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   1%|          | 3/290 [00:01<01:37,  2.94it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   1%|▏         | 4/290 [00:01<01:38,  2.90it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   2%|▏         | 5/290 [00:01<01:43,  2.75it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   2%|▏         | 6/290 [00:02<02:04,  2.28it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   2%|▏         | 7/290 [00:02<02:05,  2.25it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   3%|▎         | 8/290 [00:03<02:05,  2.25it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   3%|▎         | 9/290 [00:03<01:50,  2.54it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   3%|▎         | 10/290 [00:03<01:40,  2.78it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   4%|▍         | 11/290 [00:04<01:48,  2.57it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   4%|▍         | 12/290 [00:04<01:52,  2.47it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   4%|▍         | 13/290 [00:05<01:53,  2.44it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   5%|▍         | 14/290 [00:05<01:50,  2.50it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   5%|▌         | 15/290 [00:05<01:50,  2.49it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   6%|▌         | 16/290 [00:06<01:42,  2.68it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   6%|▌         | 17/290 [00:06<01:35,  2.85it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   6%|▌         | 18/290 [00:06<01:33,  2.90it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   7%|▋         | 19/290 [00:07<01:41,  2.67it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':   7%|▋         | 20/290 [00:07<01:37,  2.77it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':
/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  93%|█████████▎| 271/290 [02:25<00:04,  4.17it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  94%|█████████▍| 273/290 [02:25<00:02,  5.75it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  94%|█████████▍| 274/290 [02:25<00:02,  5.96it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  95%|█████████▍| 275/290 [02:25<00:02,  5.85it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  95%|█████████▌| 276/290 [02:25<00:02,  6.59it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  96%|█████████▌| 277/290 [02:26<00:01,  6.72it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  96%|█████████▌| 279/290 [02:26<00:02,  5.09it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  97%|█████████▋| 280/290 [02:27<00:02,  3.83it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  97%|█████████▋| 281/290 [02:27<00:02,  3.07it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  97%|█████████▋| 282/290 [02:28<00:03,  2.17it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  98%|█████████▊| 283/290 [02:28<00:02,  2.51it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  98%|█████████▊| 284/290 [02:29<00:03,  1.92it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  98%|█████████▊| 285/290 [02:30<00:02,  1.68it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  99%|█████████▊| 286/290 [02:30<00:02,  1.66it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  99%|█████████▉| 287/290 [02:31<00:01,  1.64it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount':  99%|█████████▉| 288/290 [02:32<00:01,  1.58it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount': 100%|█████████▉| 289/290 [02:32<00:00,  1.44it/s]C:\Users\micha\AppData\Local\Temp\ipykernel_9280\4157476950.py:24: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped = df.groupby(userid_col)[target_col].agg(agg_func)
# Scanning 'retweetcount': 100%|██████████| 290/290 [02:33<00:00,  1.89it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\torch-gpu\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'retweetcount_sum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 4
#       1 df_retweet_sum = scan_and_aggregate(input_dir=input_dir,target_col="retweetcount", agg_func=sum)
#       2 df_unique_filtered = df_unique_filtered.merge(df_retweet_sum, on="userid", how="left")
#       3 df_unique_filtered["avg_retweetcount"] = (
# ----> 4     df_unique_filtered["retweetcount_sum"] / df_unique_filtered["count"]
#       5 )
#       6 df_unique_filtered.drop(columns=["retweetcount_sum"], inplace=True)
#
# File ~\miniconda3\envs\torch-gpu\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\miniconda3\envs\torch-gpu\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'retweetcount_sum'

# %% [markdown]
# # Save to CSV #

# %%
df_unique_filtered["avg_retweetcount"] = (
    df_unique_filtered["retweetcount"] / df_unique_filtered["count"]
)
df_unique_filtered.drop(columns=["retweetcount"], inplace=True)

# %%
print("Filtered unique users saved. Remaining rows:", df_unique_filtered.shape[0])
print(df_unique_filtered.head())
# Out:
# Filtered unique users saved. Remaining rows: 2285391
#                 userid  count  totaltweets  avg_retweetcount  followers  \
# 0            173212647     54         6808          0.148148        247
# 1            335041409     27        79454          0.111111       6552
# 2  1512400441103032323   1410         2610          0.089362        165
# 3  1356632630662430722    261          955          0.095785         40
# 4             20297125     16        61432          0.062500      18173
#
#    following                                           acctdesc
# 0        278  Yeshua Hamashiach is THE answer | Romans 10:9-...
# 1       1493  Somos el periódico  #ExclusivasPuebla| Investi...
# 2        881  Shelter for abandoned dogs and cats. 1400 dogs...
# 3          5  Shelter for abandoned dogs and cats. 1400 dogs...
# 4       2178  Las mejores noticias de los dos Laredos y el m...

# %%
# Save the filtered DataFrame
df_unique_filtered.to_csv('../data/unique_users_no_intersection_unlabeled.csv', index=False)
